# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st
import time as time
from datetime import datetime
from datetime import timedelta

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last"
#other options include 'none', 'last', 'last_expr'

base='/Users/jeffdorman/Documents/python/krill_biomass/'
krilldep=pd.DataFrame()
finname= base + 'output_data/biomass/JRS_2012/2012_alldays_bio_depth_integrated.csv'
df1=pd.read_csv(finname)
krilldep=krilldep.append(df1)

finname= base + 'output_data/biomass/JRS_2013/2013_alldays_bio_depth_integrated.csv'
df2=pd.read_csv(finname)
krilldep=krilldep.append(df2)

finname= base + 'output_data/biomass/JRS_2014/2014_alldays_bio_depth_integrated.csv'
df3=pd.read_csv(finname)
krilldep=krilldep.append(df3)

finname= base + 'output_data/biomass/JRS_2015/2015_alldays_bio_depth_integrated.csv'
df4=pd.read_csv(finname)
krilldep=krilldep.append(df4)

finname= base + 'output_data/biomass/JRS_2016/2016_alldays_bio_depth_integrated.csv'
df5=pd.read_csv(finname)
krilldep=krilldep.append(df5)

finname= base + 'output_data/biomass/JRS_2017/2017_alldays_bio_depth_integrated.csv'
df6=pd.read_csv(finname)
krilldep=krilldep.append(df6)

finname= base + 'output_data/biomass/JRS_2018/2018_alldays_bio_depth_integrated.csv'
df7=pd.read_csv(finname)
krilldep=krilldep.append(df7)

krilldep.reset_index(drop=True, inplace=True)

#time_str=krilldep[' Time_M']
#dtime=list()
#for i in range(len(krilldep[' Time_M'])):
#    tmptime=krilldep.loc[i, ' Time_M']
#    tmpdate=str(krilldep.loc[i, ' Date_M'])
#    combo=tmpdate+tmptime
#    #print(combo)
#    dtime.append(datetime.strptime(combo, "%Y%m%d %H:%M:%S.%f"))#

#krilldep['d_time']=dtime

# %%
#outdf=pd.DataFrame()
#outdf['time']=krilldep['d_time']
##outdf['lon']=krilldep[' Lon_M']
#outdf['lat']=krilldep[' Lat_M']
krilldep
# Out:
#         Interval  Layer  Sv_Mean         NASC           ABC  \
# 0            1.0      2  -9999.0     0.000000  0.000000e+00
# 1            2.0      2  -9999.0     0.000000  0.000000e+00
# 2            3.0      2  -9999.0     0.000000  0.000000e+00
# 3            4.0      2  -9999.0     0.000000  0.000000e+00
# 4            5.0      2  -9999.0     0.000000  0.000000e+00
# ...          ...    ...      ...          ...           ...
# 150346     341.0      2  -9999.0  2257.115634  5.236752e-05
# 150347     342.0      2  -9999.0    14.959162  3.470687e-07
# 150348     343.0      2  -9999.0    34.208536  7.936749e-07
# 150349     344.0      2  -9999.0     0.572327  1.327861e-08
# 150350     345.0      2  -9999.0     0.000000  0.000000e+00
#
#         Total_Depth_Sampled  Layer_Depth_Min  Layer_Depth_Max    Date_M  \
# 0                      20.0             10.0             30.0  20120507
# 1                      10.0             10.0             20.0  20120507
# ...

# %%
krilldep.to_csv (base + 'output_data/biomass/allyears_bio_depth_integrated.csv', index = False, header=True)
